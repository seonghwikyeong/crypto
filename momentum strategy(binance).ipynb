# %%
import websocket
from datetime import datetime, timedelta, timezone
import numpy as np
import json
import time
import requests
from binance.client import Client
from binance.enums import *
from collections import deque
import pandas as pd
from scipy import optimize
from functools import partial
import requests

# %%
# API 키 설정
API_KEY = '9lUtP1Cs2NqkPL84OmBnAS1q2qHRyBS62hg2IpfWpEftYD5roPZJIGFVVgAbwFDm'
API_SECRET = 'eYbmAiG7d5wK9d9pSDJ52DBinurwIe6LeElJ7Wui8HmfdgziE9ocgGrYzYK6XoxS'

#텔레그램 연결
TOKEN  = "7967036104:AAFyBIclONMQrspBfTmym35-C8O9KlDgUxA"  # 여기에 너의 봇 토큰 입력
CHAT_ID  = "5034436727"

# Binance 클라이언트 생성
client = Client(API_KEY, API_SECRET, testnet=False)

# %%
tech_dict = dict()
leverage = 5
interval = "5m"  # 1분봉
entry_price = dict()
max_period = 288
open_list = deque(maxlen=max_period)
high_list = deque(maxlen=max_period)
low_list = deque(maxlen=max_period)
close_list = deque(maxlen=max_period)

symbols = ['btcusdt', 'ethusdt', 'xrpusdt','solusdt','bnbusdt','adausdt', 'dogeusdt', 'trxusdt', 'hbarusdt', 'linkusdt']
coin_data = {symbol.upper(): {"open": [], "high": [], "low": [], "close": [], "volume": []} for symbol in symbols}

symbol_precisions = {
    'btcusdt': 3,
    'ethusdt': 3,
    'xrpusdt': 0,
    'solusdt': 0,
    'bnbusdt': 2,
    'adausdt': 0,
    'dogeusdt': 0,
    'trxusdt': 0,
    'hbarusdt': 0,
    'linkusdt': 2
}

# API 키 설정
API_KEY = '9lUtP1Cs2NqkPL84OmBnAS1q2qHRyBS62hg2IpfWpEftYD5roPZJIGFVVgAbwFDm'
API_SECRET = 'eYbmAiG7d5wK9d9pSDJ52DBinurwIe6LeElJ7Wui8HmfdgziE9ocgGrYzYK6XoxS'

# Binance 클라이언트 생성
client = Client(API_KEY, API_SECRET, testnet=False)

def get_time_offset():
    server_time = requests.get('https://fapi.binance.com/fapi/v1/time').json()['serverTime']
    local_time = int(time.time() * 1000)
    return server_time - local_time


def get_position_info(symbol):
    """현재 심볼의 포지션 정보 가져오기"""
    positions = client.futures_position_information()
    for position in positions:
        if position["symbol"] == symbol.upper():
            position_size = float(position["positionAmt"])
            return position_size
    return 0

def close_position(symbol):
    """현재 포지션을 시장가로 청산"""
    position_size = get_position_info(symbol)
    if position_size == 0:
        print(f"{symbol}에 대한 열린 포지션이 없습니다.")
        return

    # 포지션 방향 확인
    side = SIDE_SELL if position_size > 0 else SIDE_BUY
    position_size = abs(position_size)  # 양수로 변환

    try:
        order = client.futures_create_order(
            symbol=symbol.upper(),
            side=side,
            type=ORDER_TYPE_MARKET,
            quantity=position_size
        )
        print(f"포지션 청산 성공: {order}")
    except Exception as e:
        print(f"포지션 청산 실패: {e}")

def set_leverage(symbol, leverage):
    """레버리지 설정"""
    try:
        response = client.futures_change_leverage(symbol=symbol.upper(), leverage=leverage, timestamp=int(time.time() * 1000 + TIME_OFFSET))
        #print(f"레버리지 설정 성공: {response}")
    except Exception as e:
        print(f"레버리지 설정 실패: {e}")

def get_market_price(symbol):
    """현재 시장가 가져오기"""
    ticker = client.futures_symbol_ticker(symbol=symbol.upper())
    return float(ticker["price"])

def calculate_position_size(position_value, market_price, symbol):
    """포지션 사이즈 계산 (코인별 precision 적용)"""
    precision = symbol_precisions.get(symbol.lower(), 2)  # 기본값 2
    size = position_value / market_price
    return round(size, precision)

def place_market_order(symbol, position_size, side):
    """시장가 주문 실행"""
    try:
        order = client.futures_create_order(
            symbol=symbol.upper(),
            side=side,
            type= ORDER_TYPE_MARKET,
            quantity=position_size,
            timestamp=int(time.time() * 1000 + TIME_OFFSET)
        )
        print("Order executed:", order)
        return True
    except Exception as e:
        print("Error placing order:", e)
        return False
    
def get_tick_size(symbol):
    """심볼의 tickSize (호가 단위) 가져오기"""
    exchange_info = client.futures_exchange_info()
    for s in exchange_info['symbols']:
        if s['symbol'] == symbol.upper():
            for f in s['filters']:
                if f['filterType'] == 'PRICE_FILTER':
                    return float(f['tickSize'])
    return 0.01  # 기본값 (예외 처리용)

def round_price_to_tick(price, tick_size):
    """tickSize에 맞게 가격 반올림"""
    return round(round(price / tick_size) * tick_size, 8)


def place_limit_order_with_auto_cancel(symbol, position_size, side, timeout=60):
    """
    최우선 호가 기준 지정가 주문 + 5분 후 미체결시 자동 취소
    """
    try:
        # 호가 정보
        order_book = client.futures_order_book(symbol=symbol.upper(), limit=5)
        tick_size = get_tick_size(symbol)

        if side == SIDE_BUY:
            best_price = float(order_book['bids'][0][0])
        elif side == SIDE_SELL:
            best_price = float(order_book['asks'][0][0])
        else:
            print("잘못된 주문 방향입니다.")
            return 0

        price = round_price_to_tick(best_price, tick_size)

        # 지정가 주문 넣기
        order = client.futures_create_order(
            symbol=symbol.upper(),
            side=side,
            type=ORDER_TYPE_LIMIT,
            quantity=position_size,
            price=price,
            timeInForce=TIME_IN_FORCE_GTC
        )
        order_id = order['orderId']
        print(f"지정가 주문 제출됨: {order_id} @ {price}")

        # 주문 체결 확인: 5분 동안 대기
        start_time = time.time()
        while time.time() - start_time < timeout:
            order_info = client.futures_get_order(symbol=symbol.upper(), orderId=order_id)
            if order_info['status'] == 'FILLED':
                print("✅ 지정가 주문 체결 완료!")
                return 2
            time.sleep(5)

        # 5분 내 체결 안 됨 → 주문 취소
        client.futures_cancel_order(symbol=symbol.upper(), orderId=order_id)
        print("⏰ 시간 초과: 지정가 주문 취소 후 시장가 진입!")

        # 시장가 주문으로 전환
        client.futures_create_order(
            symbol=symbol.upper(),
            side=side,
            type=ORDER_TYPE_MARKET,
            quantity=position_size,
            timestamp=int(time.time() * 1000 + TIME_OFFSET)
        )
        print("🚀 시장가 주문 완료!")
        return 3


    except Exception as e:
        print("오류 발생:", e)
        return 1
    

def reverse_position(symbol):
    # 현재 포지션 정보 가져오기
    positions = client.futures_position_information()
    for position in positions:
        if position["symbol"] == symbol.upper():
            position_size = float(position["positionAmt"])  # 현재 포지션 크기
            if position_size == 0:
                print("현재 포지션 없음. Reverse 불가.")
                return
            
            # 현재 포지션의 방향 (양수: 롱, 음수: 숏)
            if position_size > 0:
                reverse_side = SIDE_SELL  # 롱이면 숏으로 전환
            else:
                reverse_side = SIDE_BUY  # 숏이면 롱으로 전환

            reverse_size = abs(position_size)  # 반대 포지션으로 전환할 크기
            print(f"Reverse Order: {reverse_side} {reverse_size} {symbol}")
            
            # 지정가 주문으로 반대 포지션 실행
            success = place_market_order(symbol, reverse_size, reverse_side)
            print("Reverse 주문 완료")
            return success



def get_position_pnl(symbol):
    """현재 심볼의 포지션 수익률 계산"""
    positions = client.futures_position_information()
    for position in positions:
        if position["symbol"] == symbol.upper():
            position_size = float(position["positionAmt"])
            if position_size == 0:
                return 0, 0  # 포지션 없음
            
            entry_price = float(position["entryPrice"])  # 진입 가격
            unrealized_pnl = float(position["unRealizedProfit"])  # 실현되지 않은 손익

            # 수익률 계산
            pnl_percentage = (unrealized_pnl / (abs(position_size) * entry_price))
            return pnl_percentage, unrealized_pnl
    return 0, 0  # 기본값

def fetch_historical_klines(symbol):
    url = f"https://fapi.binance.com/fapi/v1/klines"
    params = {
        "symbol": symbol,
        "interval": interval,
        "limit": max_period,
    }
    response = requests.get(url, params=params)
    key_symbol = symbol.upper()
    if response.status_code == 200:
        data = response.json()

        coin_data[key_symbol]["open"].clear()
        coin_data[key_symbol]["high"].clear()
        coin_data[key_symbol]["low"].clear()
        coin_data[key_symbol]["close"].clear()
        coin_data[key_symbol]["volume"].clear()

        for kline in data:

            coin_data[key_symbol]["open"].append(float(kline[1]))
            coin_data[key_symbol]["high"].append(float(kline[2]))
            coin_data[key_symbol]["low"].append(float(kline[3]))
            coin_data[key_symbol]["close"].append(float(kline[4]))
            coin_data[key_symbol]["volume"].append(float(kline[5]))

        #print("초기 데이터 로드 완료:")

    else:
        print("Error fetching historical data:", response.text)

def get_usdt_balance():
    """현재 선물 계정의 USDT 잔고 가져오기"""
    try:
        balance_info = client.futures_account_balance()
        for asset in balance_info:
            if asset["asset"] == "USDT":
                return float(asset["balance"])  # 총 잔고
    except Exception as e:
        print(f"USDT 잔고 조회 실패: {e}")
    return 0  # 기본값


def send_telegram_message(message):
    url = f"https://api.telegram.org/bot{TOKEN}/sendMessage"
    data = {"chat_id": CHAT_ID, "text": message}
    response = requests.post(url, data=data)
    print(response.json())  # 응답 확인

def send_entry_message(symbol, entry_price, position_value, leverage, position):
    message = (
         " strategy 2 (momentum)\n"
        f"🚀 *{position} 진입 완료* 🚀\n"
        f"- 코인: {symbol}\n"
        f"- 가격: {entry_price:,.2f} USDT\n"
        f"- 포지션 밸류: {position_value:.4f} {symbol.replace('USDT', '')}\n"
        f"- 레버리지: {leverage}x"
    )
    send_telegram_message(message)

def send_exit_message(symbol, entry_price, exit_price, position_value, leverage, pnl, pnl_percent, position):
    message = (
         " strategy 2 (momentum)\n"
        f"✅ *{position} 청산 완료* ✅\n"
        f"- 코인: {symbol}\n"
        f"- 진입 가격: {entry_price:,.2f} USDT\n"
        f"- 청산 가격: {exit_price:,.2f} USDT\n"
        f"- 포지션 밸류: {position_value:.4f} {symbol.replace('USDT', '')}\n"
        f"- 레버리지: {leverage}x\n"
        f"- PnL: {pnl:+,.2f} USDT ({pnl_percent:+.2f}%)"
    )
    send_telegram_message(message)

def check_telegram_stop():
    url = f"https://api.telegram.org/bot{TELEGRAM_BOT_TOKEN}/getUpdates"
    response = requests.get(url)
    messages = response.json().get("result", [])

    for message in messages:
        if "message" in message and "text" in message["message"]:
            text = message["message"]["text"]
            if text.strip() == "정지":
                send_telegram_message("🚨 프로그램을 종료합니다.")
                sys.exit("사용자 요청으로 프로그램 종료됨")

def get_current_position(symbol):
    positions = client.futures_account()['positions']
    for position in positions:
        if position['symbol'] == symbol.upper():
            position_amt = float(position['positionAmt'])
            if position_amt > 0:
                return 'long'
            elif position_amt < 0:
                return 'short'
            else:
                return None
    return None # 심볼을 못 찾았을 경우

# %%
# WebSocket 메시지 처리
TIME_OFFSET = get_time_offset()
'''
def momentum_strategy(symbol):
    
    closes = coin_data[symbol]["close"]
    opens = coin_data[symbol]["open"]
    momentum = coin_data[symbol]["momentum"]

    # 3개 연속 양봉 또는 3개 연속 음봉인지 확인
    is_bullish = (momentum[-2] < 0) & (momentum[-1] >= 0) & (closes[-1] > closes[-2])
    is_bearish = (momentum[-2] < 0) & (momentum[-1] >= 0) & (closes[-1] < closes[-2])  # 음봉 3개 연속


    if not (is_bullish or is_bearish):
        print('해당사항없음')
        return 

    
    symbol = symbol.lower()
    key_symbol = symbol.upper()
    if is_bullish:
        print(key_symbol, coin_data[key_symbol]['position_value'])
        if current_position[key_symbol] == 'long':
            pass
        elif current_position[key_symbol] == 'short':

            pnl_percentage, unrealized_pnl = get_position_pnl(symbol)

            reverse_position(symbol)
            market_price = get_market_price(symbol)
            send_exit_message(symbol, entry_price, market_price, coin_data[key_symbol]['position_value'], leverage, unrealized_pnl, pnl_percentage, 'short')

            position_size = calculate_position_size(coin_data[key_symbol]['position_value'], market_price)
            place_market_order(symbol, position_size, SIDE_BUY)
            send_entry_message(symbol, entry_price, coin_data[key_symbol]['position_value'], leverage, 'long')
            current_position[key_symbol] = 'short'
        elif current_position[key_symbol] == None:
            market_price = get_market_price(symbol)
            entry_price = market_price
            position_size = calculate_position_size(coin_data[key_symbol]['position_value'], market_price)

            place_market_order(symbol, position_size, SIDE_BUY)
            send_entry_message(symbol, entry_price,coin_data[key_symbol]['position_value'], leverage, 'long')
            current_position[key_symbol] = 'long'

    elif is_bearish:
        print(key_symbol, coin_data[key_symbol]['position_value'])
        if current_position[key_symbol] == 'short':
            pass
        elif current_position[key_symbol] == 'long':

            pnl_percentage, unrealized_pnl = get_position_pnl(symbol)
            market_price = get_market_price(symbol)
            reverse_position(symbol)
            send_exit_message(symbol, entry_price, market_price, coin_data[key_symbol]['position_value'], leverage, unrealized_pnl, pnl_percentage, 'long')
            
            position_size = calculate_position_size(coin_data[key_symbol]['position_value'], market_price)
            place_market_order(symbol, position_size, SIDE_SELL)
            send_entry_message(symbol, entry_price, coin_data[key_symbol]['position_value'], leverage, 'short')

            reverse_position(symbol)
            current_position[key_symbol] = 'short'
        elif current_position[key_symbol] == None:
            market_price = get_market_price(symbol)
            entry_price = market_price
            position_size = calculate_position_size(coin_data[key_symbol]['position_value'], market_price)

            place_market_order(symbol, position_size, SIDE_SELL)
            send_entry_message(symbol, entry_price, coin_data[key_symbol]['position_value'], leverage, 'short')

            current_position[key_symbol] = 'short'
'''
def on_message(ws, message):


    global td
    data = json.loads(message)

    if "k" in data:  # Kline 데이터

        kline = data["k"]
        symbol = data["s"].upper()

        if kline["x"]:  # 캔들이 종료되었는지 확인
            open_price = float(kline["o"])
            high_price = float(kline["h"])
            low_price = float(kline["l"])
            close_price = float(kline["c"])
            
            coin_data[symbol]["open"].append(open_price)
            coin_data[symbol]["high"].append(high_price)
            coin_data[symbol]["low"].append(low_price)
            coin_data[symbol]["close"].append(close_price)
            coin_data[symbol]['return'].append((close_price-coin_data[symbol]["close"][-2])/coin_data[symbol]["close"][-2])
            
            data = coin_data[symbol]['return'][-20:]

            rolling_sum = sum(data)  # 합계
            rolling_squared_sum = sum(x**2 for x in data)  # 제곱합

            momentum = rolling_sum**2 - rolling_squared_sum
            coin_data[symbol]['momentum'].append(momentum)


            std = np.std(coin_data[symbol]['return'][-max_period:])
            btc_std = np.std(coin_data['BTCUSDT']['return'][-max_period:])
            account_balance= get_usdt_balance()
            position_value = account_balance * 0.4 * (1/std)/(1/std + 1/btc_std) * leverage
            coin_data[symbol]['position_value'] = position_value

            closes = coin_data[symbol]["close"]
            opens = coin_data[symbol]["open"]
            momentum = coin_data[symbol]["momentum"]

            # 3개 연속 양봉 또는 3개 연속 음봉인지 확인
            is_bullish = (momentum[-2] < 0) & (momentum[-1] >= 0) & (closes[-1] > closes[-2])
            is_bearish = (momentum[-2] < 0) & (momentum[-1] >= 0) & (closes[-1] < closes[-2])


            if not (is_bullish or is_bearish):
                return 

            
            symbol = symbol.lower()
            key_symbol = symbol.upper()
            current_position = get_current_position(key_symbol)
            print(key_symbol, current_position)
            if is_bullish:
                current_position = get_current_position(key_symbol)
                print(key_symbol, coin_data[key_symbol]['position_value'], 'bullish', current_position)
                if current_position == 'long':
                    pass
                elif current_position == 'short':
                    print(key_symbol, 'reverse 시점')
                    pnl_percentage, unrealized_pnl = get_position_pnl(symbol)
                    market_price = get_market_price(symbol)
                    entry_price[key_symbol] = market_price
                    
                    reverse = reverse_position(symbol)
                    print(reverse)
                    
                    if reverse :
                        print('시장가 주문 체결')
                        send_exit_message(symbol, entry_price[key_symbol], market_price, coin_data[key_symbol]['position_value'], leverage, unrealized_pnl, pnl_percentage, 'short')
                    else:
                        print('시장가 주문 실패')

                    position_size = calculate_position_size(coin_data[key_symbol]['position_value'], market_price, symbol)
                    success = place_limit_order_with_auto_cancel(symbol, position_size, SIDE_BUY)

                    if success == 2:
                        print('지정가 주문 체결')
                        send_entry_message(symbol, entry_price[key_symbol], coin_data[key_symbol]['position_value'], leverage, 'long')

                    elif success == 3:
                        print('시장가 주문 체결')
                        send_entry_message(symbol, entry_price[key_symbol], coin_data[key_symbol]['position_value'], leverage, 'long')


                    else :
                        print(f"{key_symbol}: 매수 주문 실패")

                elif current_position == None:
                    market_price = get_market_price(symbol)
                    entry_price[key_symbol] = market_price
                    position_size = calculate_position_size(coin_data[key_symbol]['position_value'], market_price, symbol)

                    success = place_limit_order_with_auto_cancel(symbol, position_size, SIDE_BUY)

                    if success == 2:
                        print('지정가 주문 체결')
                        send_entry_message(symbol, entry_price[key_symbol], coin_data[key_symbol]['position_value'], leverage, 'long')

                    elif success == 3:
                        print('시장가 주문 체결')
                        send_entry_message(symbol, entry_price[key_symbol], coin_data[key_symbol]['position_value'], leverage, 'long')

                    else :
                        print(f"{key_symbol}: 매수 주문 실패")

            elif is_bearish:
                current_position = get_current_position(key_symbol)
                print(key_symbol, coin_data[key_symbol]['position_value'], 'bearish', current_position)
                if current_position == 'short':
                    pass
                elif current_position == 'long':
                    print(key_symbol, 'reverse 시점')
                    pnl_percentage, unrealized_pnl = get_position_pnl(symbol)
                    market_price = get_market_price(symbol)
                    entry_price[key_symbol] = market_price
                    reverse = reverse_position(symbol)
                    
                    if reverse:
                        print('시장가 주문 체결')
                        send_exit_message(symbol, entry_price[key_symbol], market_price, coin_data[key_symbol]['position_value'], leverage, unrealized_pnl, pnl_percentage, 'long')
                    else :
                        print('시장가 주문 실패')

                    position_size = calculate_position_size(coin_data[key_symbol]['position_value'], market_price, symbol)
                    success = place_limit_order_with_auto_cancel(symbol, position_size, SIDE_SELL)

                    if success == 2:
                        print('지정가 주문 체결')
                        send_entry_message(symbol, entry_price[key_symbol], coin_data[key_symbol]['position_value'], leverage, 'short')

                    elif success == 3:
                        print('시장가 주문 체결')


                    else :
                        print(f"{key_symbol}: 매도 주문 실패")  

                elif current_position == None:
                    market_price = get_market_price(symbol)
                    entry_price[key_symbol] = market_price
                    position_size = calculate_position_size(coin_data[key_symbol]['position_value'], market_price, symbol)

                    success = place_limit_order_with_auto_cancel(symbol, position_size, SIDE_SELL)
                    if success == 2:
                        print('지정가 주문 체결')
                        send_entry_message(symbol, entry_price[key_symbol], coin_data[key_symbol]['position_value'], leverage, 'short')

                    elif success == 3:
                        print('시장가 주문 체결')
                        send_entry_message(symbol, entry_price[key_symbol], coin_data[key_symbol]['position_value'], leverage, 'short')

                    else :
                        print(f"{key_symbol}: 매수 주문 실패")

def on_error(ws, error):
    print(f"Error: {error}")

def on_close(ws, close_status_code, close_msg):
    print(f"WebSocket closed: {close_status_code} - {close_msg}")
    print("Reconnecting in 5 seconds...")
    time.sleep(5)
    start_websocket()  # 웹소켓 다시 실행

def on_open(ws):

    global td
    print("WebSocket 연결 성공!")
    payload = {
        "method": "SUBSCRIBE",
        "params": [f"{symbol}@kline_{interval}" for symbol in symbols],
        "id": 1
    }
    ws.send(json.dumps(payload))

def start_websocket():
    url = "wss://fstream.binance.com/ws"
    ws = websocket.WebSocketApp(
        url,
        on_message=on_message,
        on_error=on_error,
        on_close=on_close
    )
    ws.on_open = on_open
    ws.run_forever()

# %%
# 초기화
for symbol in symbols :
    key_symbol = symbol.upper()

    fetch_historical_klines(symbol)
    set_leverage(symbol, leverage)
    return_list = []
    momentum_list = []
    entry_price[key_symbol] = None

    for n, close in enumerate(coin_data[key_symbol]['close']):
        if n >= 1:
            return_list.append((coin_data[key_symbol]['close'][n] - coin_data[key_symbol]['close'][n-1])/coin_data[key_symbol]['close'][n-1])
        if n >= 20:
            data = return_list[-20:]

            rolling_sum = sum(data)  # 합계
            rolling_squared_sum = sum(x**2 for x in data)  # 제곱합

            momentum = rolling_sum**2 - rolling_squared_sum
            momentum_list.append(momentum)


    coin_data[key_symbol]['return'] = return_list
    coin_data[key_symbol]['momentum'] = momentum_list
    coin_data[key_symbol]['position_value'] = None

start_websocket()
# Out:
# WebSocket 연결 성공!
# LINKUSDT None
# LINKUSDT 631.3383618323081 bullish None
# 지정가 주문 제출됨: 39541455998 @ 11.168
# 오류 발생: APIError(code=-2013): Order does not exist.
# LINKUSDT: 매수 주문 실패
# XRPUSDT None
# XRPUSDT 553.8338276245413 bullish None
# 지정가 주문 제출됨: 96913783101 @ 1.8435
# 오류 발생: APIError(code=-2013): Order does not exist.
# XRPUSDT: 매수 주문 실패
# DOGEUSDT None
# DOGEUSDT 609.4781551332759 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# DOGEUSDT: 매수 주문 실패
# HBARUSDT None
# HBARUSDT 596.5016614191 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# HBARUSDT: 매수 주문 실패
# BNBUSDT long
# BNBUSDT 856.3690292158728 bullish long
# ETHUSDT long
# ETHUSDT 670.8322021327422 bullish long
# SOLUSDT long
# SOLUSDT 631.5664615097122 bullish long
# TRXUSDT long
# TRXUSDT 1253.0430451628213 bullish long
# ADAUSDT None
# ADAUSDT 634.3494414672166 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# ADAUSDT: 매수 주문 실패
# XRPUSDT long
# XRPUSDT 579.1534211877537 bullish long
# ETHUSDT long
# ETHUSDT 682.7134698272453 bullish long
# BTCUSDT None
# BTCUSDT 942.17376125 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# BTCUSDT: 매수 주문 실패
# LINKUSDT long
# LINKUSDT 671.9120032769205 bullish long
# ADAUSDT None
# ADAUSDT 644.6950106671363 bullish None
# 지정가 주문 제출됨: 52850070804 @ 0.5842
# 오류 발생: APIError(code=-2013): Order does not exist.
# ADAUSDT: 매수 주문 실패
# SOLUSDT long
# SOLUSDT 668.890324627717 bullish long
# TRXUSDT long
# TRXUSDT 1276.0319396165478 bullish long
# DOGEUSDT None
# DOGEUSDT 645.781490879165 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# DOGEUSDT: 매수 주문 실패
# BNBUSDT long
# BNBUSDT 905.179188468952 bullish long
# HBARUSDT None
# HBARUSDT 626.9446651374351 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# HBARUSDT: 매수 주문 실패
# DOGEUSDT None
# DOGEUSDT 671.65445842971 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# DOGEUSDT: 매수 주문 실패
# ADAUSDT long
# ADAUSDT 660.0392184200963 bullish long
# ADAUSDT long
# ADAUSDT 664.4247662041628 bullish long
# ADAUSDT long
# ADAUSDT 666.5351852825502 bullish long
# DOGEUSDT None
# DOGEUSDT 682.6666624294526 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# DOGEUSDT: 매수 주문 실패
# XRPUSDT long
# XRPUSDT 620.7496760687065 bullish long
# ETHUSDT long
# ETHUSDT 742.2047449181674 bearish long
# ETHUSDT reverse 시점
# Reverse Order: SELL 0.453 ethusdt
# Order executed: {'orderId': 8389765871403683250, 'symbol': 'ETHUSDT', 'status': 'NEW', 'clientOrderId': 'x-Cb7ytekJ4879b0a49adcfddabb00d6', 'price': '0.00', 'avgPrice': '0.00', 'origQty': '0.453', 'executedQty': '0.000', 'cumQty': '0.000', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'SELL', 'positionSide': 'BOTH', 'stopPrice': '0.00', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1744044300597}
# Reverse 주문 완료
# 시장가 주문 체결
# {'ok': True, 'result': {'message_id': 262, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744044301, 'text': 'strategy 2 (momentum)\n✅ *long 청산 완료* ✅\n- 코인: ethusdt\n- 진입 가격: 1,538.50 USDT\n- 청산 가격: 1,538.50 USDT\n- 포지션 밸류: 742.2047 ethusdt\n- 레버리지: 5x\n- PnL: +19.65 USDT (+0.03%)'}}
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# ETHUSDT: 매도 주문 실패
# SOLUSDT long
# SOLUSDT 702.6946290778766 bearish long
# SOLUSDT reverse 시점
# Reverse Order: SELL 7.0 solusdt
# Order executed: {'orderId': 110773401701, 'symbol': 'SOLUSDT', 'status': 'NEW', 'clientOrderId': 'x-Cb7ytekJ9762b89e09958ceb5eb01', 'price': '0.0000', 'avgPrice': '0.00', 'origQty': '7', 'executedQty': '0', 'cumQty': '0', 'cumQuote': '0.0000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'SELL', 'positionSide': 'BOTH', 'stopPrice': '0.0000', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1744044302250}
# Reverse 주문 완료
# 시장가 주문 체결
# {'ok': True, 'result': {'message_id': 263, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744044303, 'text': 'strategy 2 (momentum)\n✅ *long 청산 완료* ✅\n- 코인: solusdt\n- 진입 가격: 104.75 USDT\n- 청산 가격: 104.75 USDT\n- 포지션 밸류: 702.6946 solusdt\n- 레버리지: 5x\n- PnL: +27.59 USDT (+0.04%)'}}
# 지정가 주문 제출됨: 110773404181 @ 104.69
# ⏰ 시간 초과: 지정가 주문 취소 후 시장가 진입!
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# SOLUSDT: 매도 주문 실패
# DOGEUSDT None
# DOGEUSDT 716.0250166525431 bearish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# DOGEUSDT: 매수 주문 실패
# HBARUSDT None
# HBARUSDT 681.0152121521464 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# HBARUSDT: 매수 주문 실패
# ADAUSDT long
# ADAUSDT 699.1123762880635 bearish long
# ADAUSDT reverse 시점
# Reverse Order: SELL 1108.0 adausdt
# Order executed: {'orderId': 52859450864, 'symbol': 'ADAUSDT', 'status': 'NEW', 'clientOrderId': 'x-Cb7ytekJ52edd6988c7a146f596939', 'price': '0.00000', 'avgPrice': '0.00', 'origQty': '1108', 'executedQty': '0', 'cumQty': '0', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'SELL', 'positionSide': 'BOTH', 'stopPrice': '0.00000', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1744048200895}
# Reverse 주문 완료
# 시장가 주문 체결
# {'ok': True, 'result': {'message_id': 264, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744048201, 'text': 'strategy 2 (momentum)\n✅ *long 청산 완료* ✅\n- 코인: adausdt\n- 진입 가격: 0.58 USDT\n- 청산 가격: 0.58 USDT\n- 포지션 밸류: 699.1124 adausdt\n- 레버리지: 5x\n- PnL: -2.77 USDT (-0.00%)'}}
# 지정가 주문 제출됨: 52859451907 @ 0.5814
# ✅ 지정가 주문 체결 완료!
# 지정가 주문 체결
# {'ok': True, 'result': {'message_id': 265, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744048202, 'text': 'strategy 2 (momentum)\n🚀 *short 진입 완료* 🚀\n- 코인: adausdt\n- 가격: 0.58 USDT\n- 포지션 밸류: 699.1124 adausdt\n- 레버리지: 5x'}}
# TRXUSDT long
# TRXUSDT 1370.5962634857326 bullish long
# DOGEUSDT None
# DOGEUSDT 710.46513894081 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# DOGEUSDT: 매수 주문 실패
# XRPUSDT long
# XRPUSDT 646.4366338943495 bullish long
# SOLUSDT short
# SOLUSDT 720.6534289473319 bullish short
# SOLUSDT reverse 시점
# Reverse Order: BUY 5.0 solusdt
# Order executed: {'orderId': 110784240701, 'symbol': 'SOLUSDT', 'status': 'NEW', 'clientOrderId': 'x-Cb7ytekJf52b597d76acde3ed30d69', 'price': '0.0000', 'avgPrice': '0.00', 'origQty': '5', 'executedQty': '0', 'cumQty': '0', 'cumQuote': '0.0000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'BUY', 'positionSide': 'BOTH', 'stopPrice': '0.0000', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1744048801075}
# Reverse 주문 완료
# True
# 시장가 주문 체결
# {'ok': True, 'result': {'message_id': 266, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744048801, 'text': 'strategy 2 (momentum)\n✅ *short 청산 완료* ✅\n- 코인: solusdt\n- 진입 가격: 107.51 USDT\n- 청산 가격: 107.51 USDT\n- 포지션 밸류: 720.6534 solusdt\n- 레버리지: 5x\n- PnL: -14.25 USDT (-0.03%)'}}
# 지정가 주문 제출됨: 110784244041 @ 107.59
# ✅ 지정가 주문 체결 완료!
# 지정가 주문 체결
# {'ok': True, 'result': {'message_id': 267, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744048808, 'text': 'strategy 2 (momentum)\n🚀 *long 진입 완료* 🚀\n- 코인: solusdt\n- 가격: 107.51 USDT\n- 포지션 밸류: 720.6534 solusdt\n- 레버리지: 5x'}}
# LINKUSDT long
# LINKUSDT 725.9940619054048 bullish long
# TRXUSDT long
# TRXUSDT 1350.4410252206287 bullish long
# BTCUSDT None
# BTCUSDT 970.26628246 bearish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# BTCUSDT: 매수 주문 실패
# BNBUSDT long
# BNBUSDT 980.5754440762419 bearish long
# BNBUSDT reverse 시점
# Reverse Order: SELL 1.59 bnbusdt
# Order executed: {'orderId': 68806983375, 'symbol': 'BNBUSDT', 'status': 'NEW', 'clientOrderId': 'x-Cb7ytekJ1d59e00fca07a9e4530c63', 'price': '0.000', 'avgPrice': '0.00', 'origQty': '1.59', 'executedQty': '0.00', 'cumQty': '0.00', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'SELL', 'positionSide': 'BOTH', 'stopPrice': '0.000', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1744049101030}
# Reverse 주문 완료
# 시장가 주문 체결
# {'ok': True, 'result': {'message_id': 268, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744049101, 'text': 'strategy 2 (momentum)\n✅ *long 청산 완료* ✅\n- 코인: bnbusdt\n- 진입 가격: 555.17 USDT\n- 청산 가격: 555.17 USDT\n- 포지션 밸류: 980.5754 bnbusdt\n- 레버리지: 5x\n- PnL: +13.05 USDT (+0.02%)'}}
# 지정가 주문 제출됨: 68806985116 @ 554.9
# 오류 발생: APIError(code=-2013): Order does not exist.
# BNBUSDT: 매도 주문 실패
# BTCUSDT None
# BTCUSDT 982.09429441 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# BTCUSDT: 매수 주문 실패
# ADAUSDT short
# ADAUSDT 694.296128852995 bullish short
# ADAUSDT reverse 시점
# Reverse Order: BUY 1202.0 adausdt
# Order executed: {'orderId': 52860485379, 'symbol': 'ADAUSDT', 'status': 'NEW', 'clientOrderId': 'x-Cb7ytekJc99ec0b36e2233ceca8d45', 'price': '0.00000', 'avgPrice': '0.00', 'origQty': '1202', 'executedQty': '0', 'cumQty': '0', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'BUY', 'positionSide': 'BOTH', 'stopPrice': '0.00000', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1744050000841}
# Reverse 주문 완료
# True
# 시장가 주문 체결
# {'ok': True, 'result': {'message_id': 269, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744050001, 'text': 'strategy 2 (momentum)\n✅ *short 청산 완료* ✅\n- 코인: adausdt\n- 진입 가격: 0.58 USDT\n- 청산 가격: 0.58 USDT\n- 포지션 밸류: 694.2961 adausdt\n- 레버리지: 5x\n- PnL: -1.80 USDT (-0.00%)'}}
# 지정가 주문 제출됨: 52860485933 @ 0.5832
# ✅ 지정가 주문 체결 완료!
# 지정가 주문 체결
# {'ok': True, 'result': {'message_id': 270, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744050002, 'text': 'strategy 2 (momentum)\n🚀 *long 진입 완료* 🚀\n- 코인: adausdt\n- 가격: 0.58 USDT\n- 포지션 밸류: 694.2961 adausdt\n- 레버리지: 5x'}}
# HBARUSDT None
# HBARUSDT 673.0710266522772 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# HBARUSDT: 매수 주문 실패
# TRXUSDT long
# TRXUSDT 1372.4425679791907 bullish long
# DOGEUSDT None
# DOGEUSDT 705.5837756607302 bearish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# DOGEUSDT: 매수 주문 실패
# SOLUSDT long
# SOLUSDT 719.2765937622594 bearish long
# SOLUSDT reverse 시점
# Reverse Order: SELL 7.0 solusdt
# Order executed: {'orderId': 110787707005, 'symbol': 'SOLUSDT', 'status': 'NEW', 'clientOrderId': 'x-Cb7ytekJ2c78f8b9936942805bf843', 'price': '0.0000', 'avgPrice': '0.00', 'origQty': '7', 'executedQty': '0', 'cumQty': '0', 'cumQuote': '0.0000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'SELL', 'positionSide': 'BOTH', 'stopPrice': '0.0000', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1744050300872}
# Reverse 주문 완료
# 시장가 주문 체결
# {'ok': True, 'result': {'message_id': 271, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744050301, 'text': 'strategy 2 (momentum)\n✅ *long 청산 완료* ✅\n- 코인: solusdt\n- 진입 가격: 107.03 USDT\n- 청산 가격: 107.03 USDT\n- 포지션 밸류: 719.2766 solusdt\n- 레버리지: 5x\n- PnL: -3.92 USDT (-0.01%)'}}
# 지정가 주문 제출됨: 110787709310 @ 107.02
# ✅ 지정가 주문 체결 완료!
# 지정가 주문 체결
# {'ok': True, 'result': {'message_id': 272, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744050307, 'text': 'strategy 2 (momentum)\n🚀 *short 진입 완료* 🚀\n- 코인: solusdt\n- 가격: 107.03 USDT\n- 포지션 밸류: 719.2766 solusdt\n- 레버리지: 5x'}}
# ETHUSDT None
# ETHUSDT 779.7753398595853 bearish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# ETHUSDT: 매수 주문 실패
# BNBUSDT short
# BNBUSDT 986.5161028628626 bearish short
# LINKUSDT long
# LINKUSDT 730.887780842092 bearish long
# LINKUSDT reverse 시점
# Reverse Order: SELL 56.54 linkusdt
# Order executed: {'orderId': 39552139791, 'symbol': 'LINKUSDT', 'status': 'NEW', 'clientOrderId': 'x-Cb7ytekJ6fb32f31002bd06fc1116a', 'price': '0.000', 'avgPrice': '0.00', 'origQty': '56.54', 'executedQty': '0.00', 'cumQty': '0.00', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'SELL', 'positionSide': 'BOTH', 'stopPrice': '0.000', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1744050309052}
# Reverse 주문 완료
# 시장가 주문 체결
# {'ok': True, 'result': {'message_id': 273, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744050309, 'text': 'strategy 2 (momentum)\n✅ *long 청산 완료* ✅\n- 코인: linkusdt\n- 진입 가격: 11.41 USDT\n- 청산 가격: 11.41 USDT\n- 포지션 밸류: 730.8878 linkusdt\n- 레버리지: 5x\n- PnL: +14.36 USDT (+0.02%)'}}
# 지정가 주문 제출됨: 39552140375 @ 11.425
# ✅ 지정가 주문 체결 완료!
# 지정가 주문 체결
# {'ok': True, 'result': {'message_id': 274, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744050311, 'text': 'strategy 2 (momentum)\n🚀 *short 진입 완료* 🚀\n- 코인: linkusdt\n- 가격: 11.41 USDT\n- 포지션 밸류: 730.8878 linkusdt\n- 레버리지: 5x'}}
# SOLUSDT short
# SOLUSDT 728.3841315108407 bullish short
# SOLUSDT reverse 시점
# Reverse Order: BUY 7.0 solusdt
# Order executed: {'orderId': 110789156535, 'symbol': 'SOLUSDT', 'status': 'NEW', 'clientOrderId': 'x-Cb7ytekJd22d11377644d1820fbff6', 'price': '0.0000', 'avgPrice': '0.00', 'origQty': '7', 'executedQty': '0', 'cumQty': '0', 'cumQuote': '0.0000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'BUY', 'positionSide': 'BOTH', 'stopPrice': '0.0000', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1744050900719}
# Reverse 주문 완료
# True
# 시장가 주문 체결
# {'ok': True, 'result': {'message_id': 275, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744050901, 'text': 'strategy 2 (momentum)\n✅ *short 청산 완료* ✅\n- 코인: solusdt\n- 진입 가격: 106.39 USDT\n- 청산 가격: 106.39 USDT\n- 포지션 밸류: 728.3841 solusdt\n- 레버리지: 5x\n- PnL: +4.34 USDT (+0.01%)'}}
# 지정가 주문 제출됨: 110789160131 @ 106.34
# ✅ 지정가 주문 체결 완료!
# 지정가 주문 체결
# {'ok': True, 'result': {'message_id': 276, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744050902, 'text': 'strategy 2 (momentum)\n🚀 *long 진입 완료* 🚀\n- 코인: solusdt\n- 가격: 106.39 USDT\n- 포지션 밸류: 728.3841 solusdt\n- 레버리지: 5x'}}
# ADAUSDT long
# ADAUSDT 704.359204535265 bullish long
# ETHUSDT None
# ETHUSDT 796.3658912673682 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# ETHUSDT: 매수 주문 실패
# DOGEUSDT None
# DOGEUSDT 714.3202475048406 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# DOGEUSDT: 매수 주문 실패
# BTCUSDT None
# BTCUSDT 992.4317442 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# BTCUSDT: 매수 주문 실패
# XRPUSDT long
# XRPUSDT 649.7153481680026 bullish long
# LINKUSDT short
# LINKUSDT 746.0020760007126 bullish short
# LINKUSDT reverse 시점
# Reverse Order: BUY 64.05 linkusdt
# Order executed: {'orderId': 39552527171, 'symbol': 'LINKUSDT', 'status': 'NEW', 'clientOrderId': 'x-Cb7ytekJb8fabe35908d5f904e86cb', 'price': '0.000', 'avgPrice': '0.00', 'origQty': '64.05', 'executedQty': '0.00', 'cumQty': '0.00', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'BUY', 'positionSide': 'BOTH', 'stopPrice': '0.000', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1744051201814}
# Reverse 주문 완료
# True
# 시장가 주문 체결
# {'ok': True, 'result': {'message_id': 277, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744051202, 'text': 'strategy 2 (momentum)\n✅ *short 청산 완료* ✅\n- 코인: linkusdt\n- 진입 가격: 11.40 USDT\n- 청산 가격: 11.40 USDT\n- 포지션 밸류: 746.0021 linkusdt\n- 레버리지: 5x\n- PnL: +1.08 USDT (+0.00%)'}}
# 지정가 주문 제출됨: 39552527796 @ 11.399
# 오류 발생: APIError(code=-2013): Order does not exist.
# LINKUSDT: 매수 주문 실패
# HBARUSDT None
# HBARUSDT 680.8295313465147 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# HBARUSDT: 매수 주문 실패
# BNBUSDT short
# BNBUSDT 1004.1313033879603 bullish short
# BNBUSDT reverse 시점
# Reverse Order: BUY 1.77 bnbusdt
# Order executed: {'orderId': 68808436489, 'symbol': 'BNBUSDT', 'status': 'NEW', 'clientOrderId': 'x-Cb7ytekJ3f7889fed27f38ba58dbe0', 'price': '0.000', 'avgPrice': '0.00', 'origQty': '1.77', 'executedQty': '0.00', 'cumQty': '0.00', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'BUY', 'positionSide': 'BOTH', 'stopPrice': '0.000', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1744051203862}
# Reverse 주문 완료
# True
# 시장가 주문 체결
# {'ok': True, 'result': {'message_id': 278, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744051204, 'text': 'strategy 2 (momentum)\n✅ *short 청산 완료* ✅\n- 코인: bnbusdt\n- 진입 가격: 554.47 USDT\n- 청산 가격: 554.47 USDT\n- 포지션 밸류: 1004.1313 bnbusdt\n- 레버리지: 5x\n- PnL: +0.71 USDT (+0.00%)'}}
# 지정가 주문 제출됨: 68808438111 @ 554.46
# 오류 발생: APIError(code=-2013): Order does not exist.
# BNBUSDT: 매수 주문 실패
# TRXUSDT long
# TRXUSDT 1392.6699074443382 bullish long
# SOLUSDT long
# SOLUSDT 733.4456516620502 bearish long
# SOLUSDT reverse 시점
# Reverse Order: SELL 7.0 solusdt
# Order executed: {'orderId': 110796459379, 'symbol': 'SOLUSDT', 'status': 'NEW', 'clientOrderId': 'x-Cb7ytekJeb88a38e44258c4fe05de7', 'price': '0.0000', 'avgPrice': '0.00', 'origQty': '7', 'executedQty': '0', 'cumQty': '0', 'cumQuote': '0.0000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'SELL', 'positionSide': 'BOTH', 'stopPrice': '0.0000', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1744054200714}
# Reverse 주문 완료
# 시장가 주문 체결
# {'ok': True, 'result': {'message_id': 279, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744054201, 'text': 'strategy 2 (momentum)\n✅ *long 청산 완료* ✅\n- 코인: solusdt\n- 진입 가격: 105.61 USDT\n- 청산 가격: 105.61 USDT\n- 포지션 밸류: 733.4457 solusdt\n- 레버리지: 5x\n- PnL: -4.77 USDT (-0.01%)'}}
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# SOLUSDT: 매도 주문 실패
# TRXUSDT long
# TRXUSDT 1386.9752882543387 bearish long
# TRXUSDT reverse 시점
# Reverse Order: SELL 5485.0 trxusdt
# Order executed: {'orderId': 14636679126, 'symbol': 'TRXUSDT', 'status': 'NEW', 'clientOrderId': 'x-Cb7ytekJ2863b61756cf8f75798ca1', 'price': '0.00000', 'avgPrice': '0.00', 'origQty': '5485', 'executedQty': '0', 'cumQty': '0', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'SELL', 'positionSide': 'BOTH', 'stopPrice': '0.00000', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1744055100781}
# Reverse 주문 완료
# 시장가 주문 체결
# {'ok': True, 'result': {'message_id': 280, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744055101, 'text': 'strategy 2 (momentum)\n✅ *long 청산 완료* ✅\n- 코인: trxusdt\n- 진입 가격: 0.23 USDT\n- 청산 가격: 0.23 USDT\n- 포지션 밸류: 1386.9753 trxusdt\n- 레버리지: 5x\n- PnL: +8.44 USDT (+0.01%)'}}
# 지정가 주문 제출됨: 14636679415 @ 0.22753
# ✅ 지정가 주문 체결 완료!
# 지정가 주문 체결
# {'ok': True, 'result': {'message_id': 281, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744055112, 'text': 'strategy 2 (momentum)\n🚀 *short 진입 완료* 🚀\n- 코인: trxusdt\n- 가격: 0.23 USDT\n- 포지션 밸류: 1386.9753 trxusdt\n- 레버리지: 5x'}}
# BTCUSDT None
# BTCUSDT 994.11818031 bearish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# BTCUSDT: 매수 주문 실패
# DOGEUSDT None
# DOGEUSDT 716.8251999407357 bearish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# DOGEUSDT: 매수 주문 실패
# TRXUSDT short
# TRXUSDT 1397.1013284826595 bearish short
# ADAUSDT long
# ADAUSDT 707.6539091268987 bullish long
# ETHUSDT None
# ETHUSDT 806.1853842742489 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# ETHUSDT: 매수 주문 실패
# BNBUSDT long
# BNBUSDT 1015.5737258325566 bullish long
# XRPUSDT long
# XRPUSDT 648.6279040054116 bullish long
# HBARUSDT None
# HBARUSDT 680.4481418819313 bullish None
# 지정가 주문 제출됨: 10046545267 @ 0.1514
# ✅ 지정가 주문 체결 완료!
# 지정가 주문 체결
# {'ok': True, 'result': {'message_id': 282, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744058102, 'text': 'strategy 2 (momentum)\n🚀 *long 진입 완료* 🚀\n- 코인: hbarusdt\n- 가격: 0.15 USDT\n- 포지션 밸류: 680.4481 hbarusdt\n- 레버리지: 5x'}}
# DOGEUSDT None
# DOGEUSDT 716.5758421437674 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# DOGEUSDT: 매수 주문 실패
# LINKUSDT long
# LINKUSDT 748.329190622352 bullish long
# ETHUSDT None
# ETHUSDT 805.1149619887187 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# ETHUSDT: 매수 주문 실패
# SOLUSDT None
# SOLUSDT 734.836920361517 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# SOLUSDT: 매수 주문 실패
# BTCUSDT None
# BTCUSDT 993.7781051500001 bearish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# BTCUSDT: 매수 주문 실패
# BTCUSDT None
# BTCUSDT 993.7781051500001 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# BTCUSDT: 매수 주문 실패
# BNBUSDT long
# BNBUSDT 1018.912771038353 bullish long
# DOGEUSDT None
# DOGEUSDT 719.6013017389635 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# DOGEUSDT: 매수 주문 실패
# SOLUSDT None
# SOLUSDT 734.3929573271633 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# SOLUSDT: 매수 주문 실패
# BTCUSDT None
# BTCUSDT 993.7781051500001 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# BTCUSDT: 매수 주문 실패
# BTCUSDT None
# BTCUSDT 993.7781051500001 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# BTCUSDT: 매수 주문 실패
# DOGEUSDT None
# DOGEUSDT 720.394276315403 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# DOGEUSDT: 매수 주문 실패
# TRXUSDT short
# TRXUSDT 1413.2826378566888 bullish short
# TRXUSDT reverse 시점
# Reverse Order: BUY 6094.0 trxusdt
# Order executed: {'orderId': 14637466907, 'symbol': 'TRXUSDT', 'status': 'NEW', 'clientOrderId': 'x-Cb7ytekJedd022b7b5952ceb603094', 'price': '0.00000', 'avgPrice': '0.00', 'origQty': '6094', 'executedQty': '0', 'cumQty': '0', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'BUY', 'positionSide': 'BOTH', 'stopPrice': '0.00000', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1744065001227}
# Reverse 주문 완료
# True
# 시장가 주문 체결
# {'ok': True, 'result': {'message_id': 283, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744065002, 'text': 'strategy 2 (momentum)\n✅ *short 청산 완료* ✅\n- 코인: trxusdt\n- 진입 가격: 0.23 USDT\n- 청산 가격: 0.23 USDT\n- 포지션 밸류: 1413.2826 trxusdt\n- 레버리지: 5x\n- PnL: -7.14 USDT (-0.01%)'}}
# 지정가 주문 제출됨: 14637467117 @ 0.22868
# ✅ 지정가 주문 체결 완료!
# 지정가 주문 체결
# {'ok': True, 'result': {'message_id': 284, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744065033, 'text': 'strategy 2 (momentum)\n🚀 *long 진입 완료* 🚀\n- 코인: trxusdt\n- 가격: 0.23 USDT\n- 포지션 밸류: 1413.2826 trxusdt\n- 레버리지: 5x'}}
# SOLUSDT None
# SOLUSDT 726.5156306971586 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# SOLUSDT: 매수 주문 실패
# LINKUSDT long
# LINKUSDT 744.4879822485183 bullish long
# ETHUSDT None
# ETHUSDT 797.4152496151788 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# ETHUSDT: 매수 주문 실패
# DOGEUSDT None
# DOGEUSDT 714.1028822865553 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# DOGEUSDT: 매수 주문 실패
# HBARUSDT long
# HBARUSDT 673.9446811873376 bearish long
# HBARUSDT reverse 시점
# Reverse Order: SELL 4493.0 hbarusdt
# Order executed: {'orderId': 10048338961, 'symbol': 'HBARUSDT', 'status': 'NEW', 'clientOrderId': 'x-Cb7ytekJ4d1855544eca63de6ac5c3', 'price': '0.00000', 'avgPrice': '0.00', 'origQty': '4493', 'executedQty': '0', 'cumQty': '0', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'SELL', 'positionSide': 'BOTH', 'stopPrice': '0.00000', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1744066200714}
# Reverse 주문 완료
# 시장가 주문 체결
# {'ok': True, 'result': {'message_id': 285, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744066202, 'text': 'strategy 2 (momentum)\n✅ *long 청산 완료* ✅\n- 코인: hbarusdt\n- 진입 가격: 0.15 USDT\n- 청산 가격: 0.15 USDT\n- 포지션 밸류: 673.9447 hbarusdt\n- 레버리지: 5x\n- PnL: +8.22 USDT (+0.01%)'}}
# 지정가 주문 제출됨: 10048339084 @ 0.15321
# ✅ 지정가 주문 체결 완료!
# 지정가 주문 체결
# {'ok': True, 'result': {'message_id': 286, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744066213, 'text': 'strategy 2 (momentum)\n🚀 *short 진입 완료* 🚀\n- 코인: hbarusdt\n- 가격: 0.15 USDT\n- 포지션 밸류: 673.9447 hbarusdt\n- 레버리지: 5x'}}
# ETHUSDT None
# ETHUSDT 805.545860092983 bearish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# ETHUSDT: 매수 주문 실패
# DOGEUSDT None
# DOGEUSDT 719.7666808645533 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# DOGEUSDT: 매수 주문 실패
# LINKUSDT long
# LINKUSDT 749.5145415671959 bullish long
# ADAUSDT long
# ADAUSDT 708.3411476763984 bullish long
# XRPUSDT long
# XRPUSDT 654.4052465854836 bullish long
# ADAUSDT long
# ADAUSDT 709.1014766693454 bearish long
# ADAUSDT reverse 시점
# Reverse Order: SELL 1191.0 adausdt
# Order executed: {'orderId': 52867929542, 'symbol': 'ADAUSDT', 'status': 'NEW', 'clientOrderId': 'x-Cb7ytekJb94f3fecb92f2b60a7c494', 'price': '0.00000', 'avgPrice': '0.00', 'origQty': '1191', 'executedQty': '0', 'cumQty': '0', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'SELL', 'positionSide': 'BOTH', 'stopPrice': '0.00000', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1744070100452}
# Reverse 주문 완료
# 시장가 주문 체결
# {'ok': True, 'result': {'message_id': 287, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744070109, 'text': 'strategy 2 (momentum)\n✅ *long 청산 완료* ✅\n- 코인: adausdt\n- 진입 가격: 0.59 USDT\n- 청산 가격: 0.59 USDT\n- 포지션 밸류: 709.1015 adausdt\n- 레버리지: 5x\n- PnL: +2.86 USDT (+0.00%)'}}
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# ADAUSDT: 매도 주문 실패
# ETHUSDT None
# ETHUSDT 809.0893536315768 bearish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# ETHUSDT: 매수 주문 실패
# BNBUSDT long
# BNBUSDT 1023.6226625318423 bearish long
# BNBUSDT reverse 시점
# Reverse Order: SELL 1.81 bnbusdt
# Order executed: {'orderId': 68815622248, 'symbol': 'BNBUSDT', 'status': 'NEW', 'clientOrderId': 'x-Cb7ytekJ898259e3f8fa3a5b020a47', 'price': '0.000', 'avgPrice': '0.00', 'origQty': '1.81', 'executedQty': '0.00', 'cumQty': '0.00', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'SELL', 'positionSide': 'BOTH', 'stopPrice': '0.000', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1744070110408}
# Reverse 주문 완료
# 시장가 주문 체결
# {'ok': True, 'result': {'message_id': 288, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744070119, 'text': 'strategy 2 (momentum)\n✅ *long 청산 완료* ✅\n- 코인: bnbusdt\n- 진입 가격: 555.00 USDT\n- 청산 가격: 555.00 USDT\n- 포지션 밸류: 1023.6227 bnbusdt\n- 레버리지: 5x\n- PnL: +1.14 USDT (+0.00%)'}}
# 지정가 주문 제출됨: 68815625162 @ 555.01
# ⏰ 시간 초과: 지정가 주문 취소 후 시장가 진입!
# 🚀 시장가 주문 완료!
# 시장가 주문 체결
# LINKUSDT long
# LINKUSDT 753.6829599812164 bearish long
# LINKUSDT reverse 시점
# Reverse Order: SELL 65.44 linkusdt
# Order executed: {'orderId': 39557413253, 'symbol': 'LINKUSDT', 'status': 'NEW', 'clientOrderId': 'x-Cb7ytekJ415ce5a2f6b4d61b383a65', 'price': '0.000', 'avgPrice': '0.00', 'origQty': '65.44', 'executedQty': '0.00', 'cumQty': '0.00', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'SELL', 'positionSide': 'BOTH', 'stopPrice': '0.000', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1744070181222}
# Reverse 주문 완료
# 시장가 주문 체결
# {'ok': True, 'result': {'message_id': 289, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744070182, 'text': 'strategy 2 (momentum)\n✅ *long 청산 완료* ✅\n- 코인: linkusdt\n- 진입 가격: 11.44 USDT\n- 청산 가격: 11.44 USDT\n- 포지션 밸류: 753.6830 linkusdt\n- 레버리지: 5x\n- PnL: +2.23 USDT (+0.00%)'}}
# 지정가 주문 제출됨: 39557415571 @ 11.429
# ✅ 지정가 주문 체결 완료!
# 지정가 주문 체결
# {'ok': True, 'result': {'message_id': 290, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744070190, 'text': 'strategy 2 (momentum)\n🚀 *short 진입 완료* 🚀\n- 코인: linkusdt\n- 가격: 11.44 USDT\n- 포지션 밸류: 753.6830 linkusdt\n- 레버리지: 5x'}}
# SOLUSDT None
# SOLUSDT 734.2916320040534 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# SOLUSDT: 매수 주문 실패
# DOGEUSDT None
# DOGEUSDT 721.2653074928265 bearish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# DOGEUSDT: 매수 주문 실패
# ADAUSDT None
# ADAUSDT 702.1192959853108 bearish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# ADAUSDT: 매수 주문 실패
# BTCUSDT None
# BTCUSDT 997.35383275 bearish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# BTCUSDT: 매수 주문 실패
# BNBUSDT short
# BNBUSDT 1017.3104324184544 bearish short
# TRXUSDT long
# TRXUSDT 1414.5974158861761 bullish long
# ADAUSDT None
# ADAUSDT 701.9184652115109 bearish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# ADAUSDT: 매수 주문 실패
# BNBUSDT short
# BNBUSDT 1018.6754466769125 bearish short
# SOLUSDT None
# SOLUSDT 731.0591084253676 bearish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# SOLUSDT: 매수 주문 실패
# TRXUSDT long
# TRXUSDT 1413.592315685254 bullish long
# BTCUSDT None
# BTCUSDT 997.35383275 bearish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# BTCUSDT: 매수 주문 실패
# TRXUSDT long
# TRXUSDT 1413.7549175473505 bullish long
# SOLUSDT None
# SOLUSDT 729.6954253662545 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# SOLUSDT: 매수 주문 실패
# BTCUSDT None
# BTCUSDT 997.35383275 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# BTCUSDT: 매수 주문 실패
# DOGEUSDT None
# DOGEUSDT 716.171455385541 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# DOGEUSDT: 매수 주문 실패
# ETHUSDT None
# ETHUSDT 805.4090681153093 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# ETHUSDT: 매수 주문 실패
# LINKUSDT short
# LINKUSDT 753.3243053724611 bullish short
# LINKUSDT reverse 시점
# Reverse Order: BUY 65.9 linkusdt
# Order executed: {'orderId': 39559078962, 'symbol': 'LINKUSDT', 'status': 'NEW', 'clientOrderId': 'x-Cb7ytekJda0c5589661fc107fea924', 'price': '0.000', 'avgPrice': '0.00', 'origQty': '65.90', 'executedQty': '0.00', 'cumQty': '0.00', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'BUY', 'positionSide': 'BOTH', 'stopPrice': '0.000', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1744076401652}
# Reverse 주문 완료
# True
# 시장가 주문 체결
# {'ok': True, 'result': {'message_id': 291, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744076411, 'text': 'strategy 2 (momentum)\n✅ *short 청산 완료* ✅\n- 코인: linkusdt\n- 진입 가격: 11.68 USDT\n- 청산 가격: 11.68 USDT\n- 포지션 밸류: 753.3243 linkusdt\n- 레버리지: 5x\n- PnL: -16.48 USDT (-0.02%)'}}
# 지정가 주문 제출됨: 39559085285 @ 11.694
# ⏰ 시간 초과: 지정가 주문 취소 후 시장가 진입!
# 🚀 시장가 주문 완료!
# 시장가 주문 체결
# {'ok': True, 'result': {'message_id': 292, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744076473, 'text': 'strategy 2 (momentum)\n🚀 *long 진입 완료* 🚀\n- 코인: linkusdt\n- 가격: 11.68 USDT\n- 포지션 밸류: 753.3243 linkusdt\n- 레버리지: 5x'}}
# ADAUSDT None
# ADAUSDT 690.713305837145 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# ADAUSDT: 매수 주문 실패
# BNBUSDT short
# BNBUSDT 1005.1398752424495 bullish short
# BNBUSDT reverse 시점
# Reverse Order: BUY 1.84 bnbusdt
# Order executed: {'orderId': 68818188945, 'symbol': 'BNBUSDT', 'status': 'NEW', 'clientOrderId': 'x-Cb7ytekJ56e4997670a8962c50dbba', 'price': '0.000', 'avgPrice': '0.00', 'origQty': '1.84', 'executedQty': '0.00', 'cumQty': '0.00', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'BUY', 'positionSide': 'BOTH', 'stopPrice': '0.000', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1744076474177}
# Reverse 주문 완료
# True
# 시장가 주문 체결
# {'ok': True, 'result': {'message_id': 293, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744076476, 'text': 'strategy 2 (momentum)\n✅ *short 청산 완료* ✅\n- 코인: bnbusdt\n- 진입 가격: 561.96 USDT\n- 청산 가격: 561.96 USDT\n- 포지션 밸류: 1005.1399 bnbusdt\n- 레버리지: 5x\n- PnL: -14.04 USDT (-0.01%)'}}
# 지정가 주문 제출됨: 68818189975 @ 561.93
# ✅ 지정가 주문 체결 완료!
# 지정가 주문 체결
# {'ok': True, 'result': {'message_id': 294, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744076509, 'text': 'strategy 2 (momentum)\n🚀 *long 진입 완료* 🚀\n- 코인: bnbusdt\n- 가격: 561.96 USDT\n- 포지션 밸류: 1005.1399 bnbusdt\n- 레버리지: 5x'}}
# XRPUSDT long
# XRPUSDT 631.3229539979486 bullish long
# DOGEUSDT None
# DOGEUSDT 692.7300723258638 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# DOGEUSDT: 매수 주문 실패
# ADAUSDT None
# ADAUSDT 679.954816652562 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# ADAUSDT: 매수 주문 실패
# HBARUSDT short
# HBARUSDT 661.9487364411207 bullish short
# HBARUSDT reverse 시점
# Reverse Order: BUY 4399.0 hbarusdt
# Order executed: {'orderId': 10053239724, 'symbol': 'HBARUSDT', 'status': 'NEW', 'clientOrderId': 'x-Cb7ytekJ512543148db431109de2fb', 'price': '0.00000', 'avgPrice': '0.00', 'origQty': '4399', 'executedQty': '0', 'cumQty': '0', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'BUY', 'positionSide': 'BOTH', 'stopPrice': '0.00000', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1744083000550}
# Reverse 주문 완료
# True
# 시장가 주문 체결
# {'ok': True, 'result': {'message_id': 295, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744083005, 'text': 'strategy 2 (momentum)\n✅ *short 청산 완료* ✅\n- 코인: hbarusdt\n- 진입 가격: 0.16 USDT\n- 청산 가격: 0.16 USDT\n- 포지션 밸류: 661.9487 hbarusdt\n- 레버리지: 5x\n- PnL: -8.62 USDT (-0.01%)'}}
# 지정가 주문 제출됨: 10053242480 @ 0.15518
# ⏰ 시간 초과: 지정가 주문 취소 후 시장가 진입!
# 🚀 시장가 주문 완료!
# 시장가 주문 체결
# {'ok': True, 'result': {'message_id': 296, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744083068, 'text': 'strategy 2 (momentum)\n🚀 *long 진입 완료* 🚀\n- 코인: hbarusdt\n- 가격: 0.16 USDT\n- 포지션 밸류: 661.9487 hbarusdt\n- 레버리지: 5x'}}
# BTCUSDT None
# BTCUSDT 956.0682120900001 bearish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# BTCUSDT: 매수 주문 실패
# XRPUSDT long
# XRPUSDT 630.9789380067809 bearish long
# XRPUSDT reverse 시점
# Reverse Order: SELL 300.0 xrpusdt
# Order executed: {'orderId': 97042731251, 'symbol': 'XRPUSDT', 'status': 'NEW', 'clientOrderId': 'x-Cb7ytekJbeb8da71d65d457b86fd4d', 'price': '0.0000', 'avgPrice': '0.00', 'origQty': '300.0', 'executedQty': '0.0', 'cumQty': '0.0', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'SELL', 'positionSide': 'BOTH', 'stopPrice': '0.0000', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1744084200620}
# Reverse 주문 완료
# 시장가 주문 체결
# {'ok': True, 'result': {'message_id': 297, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744084202, 'text': 'strategy 2 (momentum)\n✅ *long 청산 완료* ✅\n- 코인: xrpusdt\n- 진입 가격: 1.90 USDT\n- 청산 가격: 1.90 USDT\n- 포지션 밸류: 630.9789 xrpusdt\n- 레버리지: 5x\n- PnL: +16.53 USDT (+0.03%)'}}
# 지정가 주문 제출됨: 97042736062 @ 1.8977
# ✅ 지정가 주문 체결 완료!
# 지정가 주문 체결
# {'ok': True, 'result': {'message_id': 298, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744084208, 'text': 'strategy 2 (momentum)\n🚀 *short 진입 완료* 🚀\n- 코인: xrpusdt\n- 가격: 1.90 USDT\n- 포지션 밸류: 630.9789 xrpusdt\n- 레버리지: 5x'}}
# DOGEUSDT None
# DOGEUSDT 706.9011219503013 bearish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# DOGEUSDT: 매수 주문 실패
# BTCUSDT None
# BTCUSDT 972.1875198100001 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# BTCUSDT: 매수 주문 실패
# ETHUSDT None
# ETHUSDT 791.0475705777845 bearish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# ETHUSDT: 매수 주문 실패
# ADAUSDT None
# ADAUSDT 689.6571097744237 bearish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# ADAUSDT: 매수 주문 실패
# BNBUSDT long
# BNBUSDT 1007.218907052598 bearish long
# BNBUSDT reverse 시점
# Reverse Order: SELL 1.79 bnbusdt
# Order executed: {'orderId': 68823708469, 'symbol': 'BNBUSDT', 'status': 'NEW', 'clientOrderId': 'x-Cb7ytekJeaf1dc3ef7d354cc0486ad', 'price': '0.000', 'avgPrice': '0.00', 'origQty': '1.79', 'executedQty': '0.00', 'cumQty': '0.00', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'SELL', 'positionSide': 'BOTH', 'stopPrice': '0.000', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1744084500738}
# Reverse 주문 완료
# 시장가 주문 체결
# {'ok': True, 'result': {'message_id': 299, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744084505, 'text': 'strategy 2 (momentum)\n✅ *long 청산 완료* ✅\n- 코인: bnbusdt\n- 진입 가격: 560.93 USDT\n- 청산 가격: 560.93 USDT\n- 포지션 밸류: 1007.2189 bnbusdt\n- 레버리지: 5x\n- PnL: -1.72 USDT (-0.00%)'}}
# 지정가 주문 제출됨: 68823710204 @ 561.08
# ⏰ 시간 초과: 지정가 주문 취소 후 시장가 진입!
# 🚀 시장가 주문 완료!
# 시장가 주문 체결
# HBARUSDT long
# HBARUSDT 668.1372067966261 bullish long
# DOGEUSDT None
# DOGEUSDT 705.1039191019164 bearish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# DOGEUSDT: 매수 주문 실패
# XRPUSDT short
# XRPUSDT 640.8664699541406 bearish short
# HBARUSDT long
# HBARUSDT 667.4846168267085 bullish long
# TRXUSDT long
# TRXUSDT 1378.9759993588493 bullish long
# BNBUSDT short
# BNBUSDT 1007.107320498871 bullish short
# BNBUSDT reverse 시점
# Reverse Order: BUY 1.8 bnbusdt
# Order executed: {'orderId': 68824794683, 'symbol': 'BNBUSDT', 'status': 'NEW', 'clientOrderId': 'x-Cb7ytekJd8ed952cfb008e630746a5', 'price': '0.000', 'avgPrice': '0.00', 'origQty': '1.80', 'executedQty': '0.00', 'cumQty': '0.00', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'BUY', 'positionSide': 'BOTH', 'stopPrice': '0.000', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1744086300712}
# Reverse 주문 완료
# True
# 시장가 주문 체결
# {'ok': True, 'result': {'message_id': 300, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744086301, 'text': 'strategy 2 (momentum)\n✅ *short 청산 완료* ✅\n- 코인: bnbusdt\n- 진입 가격: 563.59 USDT\n- 청산 가격: 563.59 USDT\n- 포지션 밸류: 1007.1073 bnbusdt\n- 레버리지: 5x\n- PnL: -4.92 USDT (-0.00%)'}}
# 지정가 주문 제출됨: 68824797970 @ 563.47
# ⏰ 시간 초과: 지정가 주문 취소 후 시장가 진입!
# 🚀 시장가 주문 완료!
# 시장가 주문 체결
# {'ok': True, 'result': {'message_id': 301, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744086367, 'text': 'strategy 2 (momentum)\n🚀 *long 진입 완료* 🚀\n- 코인: bnbusdt\n- 가격: 563.59 USDT\n- 포지션 밸류: 1007.1073 bnbusdt\n- 레버리지: 5x'}}
# BNBUSDT long
# BNBUSDT 1000.6179048066499 bullish long
# BNBUSDT long
# BNBUSDT 1001.2688357167029 bullish long
# LINKUSDT long
# LINKUSDT 734.9496101078487 bullish long
# BTCUSDT None
# BTCUSDT 963.62647338 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# BTCUSDT: 매수 주문 실패
# ETHUSDT None
# ETHUSDT 782.9179620951687 bullish None
# 오류 발생: APIError(code=-2019): Margin is insufficient.
# ETHUSDT: 매수 주문 실패
# TRXUSDT long
# TRXUSDT 1368.5103373972784 bearish long
# TRXUSDT reverse 시점
# Reverse Order: SELL 6180.0 trxusdt
# Order executed: {'orderId': 14639739139, 'symbol': 'TRXUSDT', 'status': 'NEW', 'clientOrderId': 'x-Cb7ytekJcd537edef7cd048dc78c55', 'price': '0.00000', 'avgPrice': '0.00', 'origQty': '6180', 'executedQty': '0', 'cumQty': '0', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'SELL', 'positionSide': 'BOTH', 'stopPrice': '0.00000', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1744088701274}
# Reverse 주문 완료
# 시장가 주문 체결
# {'ok': True, 'result': {'message_id': 302, 'from': {'id': 7967036104, 'is_bot': True, 'first_name': 'crypto trading bot', 'username': 'hk_crypto_tradingbot'}, 'chat': {'id': 5034436727, 'first_name': '휘경', 'last_name': '성', 'type': 'private'}, 'date': 1744088702, 'text': 'strategy 2 (momentum)\n✅ *long 청산 완료* ✅\n- 코인: trxusdt\n- 진입 가격: 0.23 USDT\n- 청산 가격: 0.23 USDT\n- 포지션 밸류: 1368.5103 trxusdt\n- 레버리지: 5x\n- PnL: +31.12 USDT (+0.02%)'}}
# 지정가 주문 제출됨: 14639739688 @ 0.23365
# ✅ 지정가 주문 체결 완료!
# 지정가 주문 체결
# ...
# Error: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# Error: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# Error: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# Error: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# Error: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# Error: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# Error: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# Error: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# Error: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# Error: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# Error: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# Error: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# Error: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# Error: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# Error: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# Error: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# Error: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# Error: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# USDT 잔고 조회 실패: APIError(code=-1021): Timestamp for this request was 1000ms ahead of the server's time.
# Error:
# WebSocket closed: None - None
# Reconnecting in 5 seconds...
# WebSocket 연결 성공!
# Error:
# WebSocket closed: None - None
# Reconnecting in 5 seconds...
# WebSocket 연결 성공!
